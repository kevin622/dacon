# %% [markdown]
# ## 맨날 하는 그거

# %%
import pandas as pd
import numpy as np

# %%
train_x_df = pd.read_csv('data/train_x_df.csv')
train_y_df = pd.read_csv('data/train_y_df.csv')
train_x_df.head()
# Out:
#    sample_id  time  coin_index      open      high       low     close  \
# 0          0     0           7  1.010004  1.010004  1.009612  1.010004
# 1          0     1           7  1.009808  1.009808  1.009808  1.009808
# 2          0     2           7  1.009808  1.010200  1.009808  1.010200
# 3          0     3           7  1.010200  1.011181  1.010200  1.011181
# 4          0     4           7  1.010985  1.010985  1.010200  1.010200
#
#          volume       quote_av      trades    tb_base_av    tb_quote_av
# 0  8.382875e+05   43160.632812  451.157288  7.326834e+05   37725.183594
# 1  1.622420e+05    8352.220703   39.231071  0.000000e+00       0.000000
# 2  1.664967e+04     857.377808   58.846603  1.664967e+04     857.377808
# 3  2.586971e+06  133310.343750  431.541779  2.189147e+06  112811.046875
# 4  1.129996e+06   58216.867188  176.539810  0.000000e+00       0.000000

# %%
train_x_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10159560 entries, 0 to 10159559
# Data columns (total 12 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   sample_id    int64
#  1   time         int64
#  2   coin_index   int64
#  3   open         float64
#  4   high         float64
#  5   low          float64
#  6   close        float64
#  7   volume       float64
#  8   quote_av     float64
#  9   trades       float64
#  10  tb_base_av   float64
#  11  tb_quote_av  float64
# dtypes: float64(9), int64(3)
# memory usage: 930.1 MB

# %%
train_y_df.head()
# Out:
#    sample_id  time  coin_index      open      high       low     close  \
# 0          0     0           7  1.000392  1.000588  1.000392  1.000588
# 1          0     1           7  1.000588  1.001177  1.000392  1.001177
# 2          0     2           7  1.001177  1.001177  1.001177  1.001177
# 3          0     3           7  1.001177  1.001373  1.001177  1.001373
# 4          0     4           7  1.000981  1.000981  0.999804  1.000196
#
#          volume       quote_av      trades    tb_base_av   tb_quote_av
# 0  8.305119e+05   42356.179688  137.308746  8.305119e+05  42356.179688
# 1  5.320066e+05   27140.638672  294.233032  4.882738e+05  24909.861328
# 2  5.113770e+05   26100.681641   58.846603  5.113770e+05  26100.681641
# 3  1.134853e+06   57929.410156  137.308746  1.095514e+06  55921.156250
# 4  5.801173e+06  295872.343750  666.928162  9.911239e+05  50528.589844

# %%
train_y_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883440 entries, 0 to 883439
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   sample_id    883440 non-null  int64
#  1   time         883440 non-null  int64
#  2   coin_index   883440 non-null  int64
#  3   open         883440 non-null  float64
#  4   high         883440 non-null  float64
#  5   low          883440 non-null  float64
#  6   close        883440 non-null  float64
#  7   volume       883440 non-null  float64
#  8   quote_av     883440 non-null  float64
#  9   trades       883440 non-null  float64
#  10  tb_base_av   883440 non-null  float64
#  11  tb_quote_av  883440 non-null  float64
# dtypes: float64(9), int64(3)
# memory usage: 80.9 MB

# %% [markdown]
# ## 7번 코인 1번 샘플만 보자

# %%
df = train_x_df[train_x_df.coin_index==7][train_x_df.sample_id==0]
# Out:
# <ipython-input-19-0987e4a4d565>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = train_x_df[train_x_df.coin_index==7][train_x_df.sample_id==0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1380 entries, 0 to 1379
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sample_id    1380 non-null   int64
#  1   time         1380 non-null   int64
#  2   coin_index   1380 non-null   int64
#  3   open         1380 non-null   float64
#  4   high         1380 non-null   float64
#  5   low          1380 non-null   float64
#  6   close        1380 non-null   float64
#  7   volume       1380 non-null   float64
#  8   quote_av     1380 non-null   float64
#  9   trades       1380 non-null   float64
#  10  tb_base_av   1380 non-null   float64
#  11  tb_quote_av  1380 non-null   float64
# dtypes: float64(9), int64(3)
# memory usage: 140.2 KB

# %%
df.head()
# Out:
#    sample_id  time  coin_index      open      high       low     close  \
# 0          0     0           7  1.010004  1.010004  1.009612  1.010004
# 1          0     1           7  1.009808  1.009808  1.009808  1.009808
# 2          0     2           7  1.009808  1.010200  1.009808  1.010200
# 3          0     3           7  1.010200  1.011181  1.010200  1.011181
# 4          0     4           7  1.010985  1.010985  1.010200  1.010200
#
#          volume       quote_av      trades    tb_base_av    tb_quote_av
# 0  8.382875e+05   43160.632812  451.157288  7.326834e+05   37725.183594
# 1  1.622420e+05    8352.220703   39.231071  0.000000e+00       0.000000
# 2  1.664967e+04     857.377808   58.846603  1.664967e+04     857.377808
# 3  2.586971e+06  133310.343750  431.541779  2.189147e+06  112811.046875
# 4  1.129996e+06   58216.867188  176.539810  0.000000e+00       0.000000

# %% [markdown]
# ### 그래프라도 좀 그려볼까

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,7))
plt.plot(df.high, color='skyblue', label='high', alpha=0.5)
plt.plot(df.low, color='darkblue', label='low', alpha=0.5)
plt.plot(df.open, color='darkgreen', label='open', alpha=0.5)
plt.plot(df.close, color='lightgreen', label='close', alpha=0.5)
plt.grid()
plt.legend()

# %%
i = 1
plt.figure(figsize=(15,10))
for col_name in ['open',  'close', 'high', 'low',]:
    plt.subplot(2, 2, i)
    plt.plot(df.time, df[col_name], color='skyblue')
    plt.grid()
    plt.title(col_name)
    plt.xlabel('time')
    i += 1

# %% [markdown]
# 다 똑같아 보인다!

# %%
i = 1
plt.figure(figsize=(20,10))
for col_name in ['volume', 'quote_av', 'trades', 'tb_base_av', 'tb_quote_av',]:
    plt.subplot(3, 2, i)
    plt.plot(df.time, df[col_name], color='skyblue')
    plt.grid()
    plt.title(col_name)
    i += 1

# %% [markdown]
# ### 질문들

# %%
df.open
# Out:
# 0       1.010004
# 1       1.009808
# 2       1.009808
# 3       1.010200
# 4       1.010985
#           ...
# 1375    0.999608
# 1376    1.000196
# 1377    0.999804
# 1378    1.000392
# 1379    1.000000
# Name: open, Length: 1380, dtype: float64

# %%
df.trades.shift()
# Out:
# 0              NaN
# 1       451.157288
# 2        39.231071
# 3        58.846603
# 4       431.541779
#            ...
# 1375      0.000000
# 1376    196.155350
# 1377     58.846603
# 1378    156.924286
# 1379    215.770889
# Name: trades, Length: 1380, dtype: float64

# %%
# 해당 시간 거래량으로 다음 시간 가격을 예측할 수 있을까?
import seaborn as sns
plt.figure(figsize=(10,5))
sns.regplot(x=df.trades.shift(), y=df.open)
# Out:
# <AxesSubplot:xlabel='trades', ylabel='open'>

# %%
df.sort_values('trades', ascending=False).head(10)
# Out:
#      sample_id  time  coin_index      open      high       low     close  \
# 271          0   271           7  0.982542  0.982542  0.979011  0.980973
# 275          0   275           7  0.981365  0.981365  0.977246  0.980188
# 267          0   267           7  0.986269  0.987250  0.984504  0.985681
# 151          0   151           7  0.993723  0.993723  0.990585  0.990781
# 757          0   757           7  1.010985  1.014123  1.010592  1.013535
# 285          0   285           7  0.986661  0.988427  0.985288  0.985288
# 284          0   284           7  0.985877  0.987642  0.985484  0.986465
# 266          0   266           7  0.989996  0.989996  0.985877  0.986858
# 57           0    57           7  1.003138  1.004119  1.001569  1.001569
# 359          0   359           7  0.994115  0.997254  0.994115  0.996469
#
#          volume      quote_av       trades  tb_base_av   tb_quote_av
# 271  44420740.0  2.220159e+06  7316.594727  18443836.0  9.220828e+05
# 275  34190140.0  1.706267e+06  4727.343750  12089763.0  6.034846e+05
# 267  23309674.0  1.170981e+06  4040.800293   6045877.0  3.039008e+05
# 151  33849488.0  1.711369e+06  3099.254395   6634156.5  3.355616e+05
# 757  31890978.0  1.646662e+06  3020.792480  29031174.0  1.499022e+06
# 285  23001016.0  1.157532e+06  2706.943848  14821118.0  7.461449e+05
# 284  28872990.0  1.452137e+06  2550.019531  12255076.0  6.163043e+05
# 266  19472986.0  9.799851e+05  2530.404053   6004287.5  3.020404e+05
# 57    9867534.0  5.045570e+05  2412.710693   3813030.5  1.950501e+05
# 359  20132598.0  1.021801e+06  2196.939941  13461343.0  6.832546e+05

# %%
temp_df = df.sort_values('trades', ascending=False)[10:]
plt.figure(figsize=(10,5))
sns.regplot(x=temp_df.trades.shift(), y=temp_df.open)
# Out:
# <AxesSubplot:xlabel='trades', ylabel='open'>

# %%
temp_df = df.sort_values('trades', ascending=False)[10:]
plt.figure(figsize=(10,5))
sns.regplot(x=temp_df.trades.shift(10), y=temp_df.open)
# Out:
# <AxesSubplot:xlabel='trades', ylabel='open'>

# %% [markdown]
# 비교적 랜덤...한 듯이 보인다..?
