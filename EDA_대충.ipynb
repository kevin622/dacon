# %% [markdown]
# ![data](https://image.slidesharecdn.com/bittradercompetition1-210308054315/95/bittrader-competition-1-24-1024.jpg?cb=1615182226)

# %% [markdown]
# ## 맨날 하는 그거

# %%
import pandas as pd
import numpy as np

# %%
train_x_df = pd.read_csv('data/train_x_df.csv')
train_y_df = pd.read_csv('data/train_y_df.csv')
train_x_df.head()
# Out:
#    sample_id  time  coin_index      open      high       low     close  \
# 0          0     0           9  0.983614  0.983614  0.983128  0.983246
# 1          0     1           9  0.983245  0.983612  0.982453  0.982693
# 2          0     2           9  0.982694  0.983612  0.982403  0.983002
# 3          0     3           9  0.983009  0.984848  0.983009  0.984486
# 4          0     4           9  0.984233  0.984606  0.983612  0.984164
#
#      volume   quote_av    trades  tb_base_av  tb_quote_av
# 0  0.001334  10.650987  0.009855    0.000848     6.771755
# 1  0.001425  11.375689  0.016137    0.000697     5.565188
# 2  0.001542  12.301942  0.014166    0.000905     7.225459
# 3  0.002520  20.134695  0.021557    0.001171     9.353000
# 4  0.002818  22.515448  0.021434    0.001799    14.372534

# %%
test_x_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 738300 entries, 0 to 738299
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   sample_id    738300 non-null  int64
#  1   time         738300 non-null  int64
#  2   coin_index   738300 non-null  int64
#  3   open         738300 non-null  float64
#  4   high         738300 non-null  float64
#  5   low          738300 non-null  float64
#  6   close        738300 non-null  float64
#  7   volume       738300 non-null  float64
#  8   quote_av     738300 non-null  float64
#  9   trades       738300 non-null  float64
#  10  tb_base_av   738300 non-null  float64
#  11  tb_quote_av  738300 non-null  float64
# dtypes: float64(9), int64(3)
# memory usage: 67.6 MB

# %%
test_x_df = pd.read_csv('data/test_x_df.csv')
test_x_df
# Out:
#         sample_id  time  coin_index      open      high       low     close  \
# 0            7661     0           7  0.993560  0.993560  0.990477  0.991021
# 1            7661     1           7  0.990771  0.993048  0.990357  0.992689
# 2            7661     2           7  0.992710  0.993560  0.991316  0.991795
# 3            7661     3           7  0.992318  0.992318  0.990695  0.990727
# 4            7661     4           7  0.991141  0.991152  0.989158  0.989605
# ...           ...   ...         ...       ...       ...       ...       ...
# 738295       8195  1375           6  0.997053  0.999276  0.997053  0.999069
# 738296       8195  1376           6  0.999121  1.000569  0.998552  1.000569
# 738297       8195  1377           6  1.000569  1.001086  0.999121  0.999690
# 738298       8195  1378           6  0.999690  1.000207  0.998863  1.000000
# 738299       8195  1379           6  1.000000  1.001137  0.999328  0.999380
#
#                volume       quote_av      trades     tb_base_av    tb_quote_av
# 0       587512.625000  534685.312500  553.533691   76317.687500   69457.835938
# 1       616675.437500  560815.937500  514.306885  291661.375000  265331.843750
# 2       670641.687500  610829.625000  361.758240  288066.125000  262389.562500
# 3       365400.343750  332430.937500  329.069244  113585.000000  103350.929688
# 4       245272.531250  222917.734375  481.617889   70405.781250   63988.847656
# ...               ...            ...         ...            ...            ...
# 738295       1.633000     315.307526    1.375175       0.878884     169.736862
# 738296       1.478406     285.818695    1.039136       0.455307      88.052055
# 738297       0.848792     164.188950    0.935739       0.445028      86.055450
# 738298       1.099217     212.537872    0.723776       0.410302      79.334801
# 738299       2.253381     436.007904    1.209740       1.453545     281.218933
#
# [738300 rows x 12 columns]

# %%
train_x_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10572180 entries, 0 to 10572179
# Data columns (total 12 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   sample_id    int64
#  1   time         int64
#  2   coin_index   int64
#  3   open         float64
#  4   high         float64
#  5   low          float64
#  6   close        float64
#  7   volume       float64
#  8   quote_av     float64
#  9   trades       float64
#  10  tb_base_av   float64
#  11  tb_quote_av  float64
# dtypes: float64(9), int64(3)
# memory usage: 967.9 MB

# %%
train_x_df.isnull().any()
# Out:
# sample_id      False
# time           False
# coin_index     False
# open           False
# high           False
# low            False
# close          False
# volume         False
# quote_av       False
# trades         False
# tb_base_av     False
# tb_quote_av    False
# dtype: bool

# %% [markdown]
# NaN이 하나도 없다??

# %%
train_y_df.head()
# Out:
#    sample_id  time  coin_index      open      high       low     close  \
# 0          0     0           9  0.999389  0.999630  0.999261  0.999385
# 1          0     1           9  0.999593  1.000000  0.999265  0.999266
# 2          0     2           9  0.999266  0.999618  0.999262  0.999322
# 3          0     3           9  0.999322  0.999388  0.998917  0.999387
# 4          0     4           9  0.999015  0.999015  0.997631  0.998399
#
#      volume   quote_av    trades  tb_base_av  tb_quote_av
# 0  0.001187   9.632785  0.012565    0.000605     4.904978
# 1  0.004197  34.052364  0.020572    0.003014    24.453999
# 2  0.003942  31.981472  0.016630    0.002967    24.069899
# 3  0.003663  29.709074  0.019463    0.002362    19.158766
# 4  0.003266  26.466251  0.030180    0.001533    12.421005

# %%
train_y_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 919320 entries, 0 to 919319
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   sample_id    919320 non-null  int64
#  1   time         919320 non-null  int64
#  2   coin_index   919320 non-null  int64
#  3   open         919320 non-null  float64
#  4   high         919320 non-null  float64
#  5   low          919320 non-null  float64
#  6   close        919320 non-null  float64
#  7   volume       919320 non-null  float64
#  8   quote_av     919320 non-null  float64
#  9   trades       919320 non-null  float64
#  10  tb_base_av   919320 non-null  float64
#  11  tb_quote_av  919320 non-null  float64
# dtypes: float64(9), int64(3)
# memory usage: 84.2 MB

# %% [markdown]
# ## 7번 코인 1번 샘플만 보자

# %%
df = train_x_df[train_x_df.coin_index==7][train_x_df.sample_id==4]
# Out:
# <ipython-input-21-fa43322de9a2>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = train_x_df[train_x_df.coin_index==7][train_x_df.sample_id==4]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1380 entries, 5520 to 6899
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sample_id    1380 non-null   int64
#  1   time         1380 non-null   int64
#  2   coin_index   1380 non-null   int64
#  3   open         1380 non-null   float64
#  4   high         1380 non-null   float64
#  5   low          1380 non-null   float64
#  6   close        1380 non-null   float64
#  7   volume       1380 non-null   float64
#  8   quote_av     1380 non-null   float64
#  9   trades       1380 non-null   float64
#  10  tb_base_av   1380 non-null   float64
#  11  tb_quote_av  1380 non-null   float64
# dtypes: float64(9), int64(3)
# memory usage: 140.2 KB

# %%
df.head()
# Out:
#       sample_id  time  coin_index      open      high       low     close  \
# 5520          4     0           7  1.006394  1.007161  1.003836  1.004092
# 5521          4     1           7  1.005882  1.010742  1.004092  1.004348
# 5522          4     2           7  1.006138  1.006138  1.000767  1.001023
# 5523          4     3           7  1.000767  1.001023  0.990281  0.990281
# 5524          4     4           7  0.990281  0.994885  0.989258  0.992327
#
#           volume      quote_av       trades   tb_base_av    tb_quote_av
# 5520  35647996.0  1.401310e+06  1023.017944   1836371.00   72158.468750
# 5521   5433885.0  2.138955e+05  1432.225098   3842025.75  151328.984375
# 5522  13401995.0  5.252012e+05  1227.621582  10635655.00  416669.625000
# 5523  91484968.0  3.564226e+06  4782.608887  16984042.00  660468.500000
# 5524  49337108.0  1.912876e+06  3094.629150  11809545.00  457693.031250

# %% [markdown]
# ### 그래프라도 좀 그려볼까

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
plt.plot(df.high, color='skyblue', label='high', alpha=0.5)
plt.plot(df.low, color='darkblue', label='low', alpha=0.5)
plt.plot(df.open, color='darkgreen', label='open', alpha=0.5)
plt.plot(df.close, color='lightgreen', label='close', alpha=0.5)
plt.grid()
plt.legend()

# %%
i = 1
plt.figure(figsize=(15,10))
for col_name in ['open',  'close', 'high', 'low',]:
    plt.subplot(2, 2, i)
    plt.plot(df.time, df[col_name], color='skyblue')
    plt.grid()
    plt.title(col_name)
    plt.xlabel('time')
    i += 1

# %% [markdown]
# 다 똑같아 보인다!

# %%
i = 1
plt.figure(figsize=(20,20))
for col_name in ['volume', 'quote_av', 'trades', 'tb_base_av', 'tb_quote_av',]:
    plt.subplot(6, 1, i)
    plt.plot(df.time, df[col_name], color='skyblue')
    plt.grid()
    plt.title(col_name)
    i += 1

# %% [markdown]
# ## 특징 찾기

# %%
coin = 0
df_x = train_x_df[train_x_df.coin_index==coin]
df_y = train_y_df[train_y_df.coin_index==coin]

# %%
# x, y 데이터의 분산??? 간단 비교
cases = []
for s_i in df_x.sample_id.unique():
    open_vals_x = df_x[df_x.sample_id==s_i].open
    max_val_x = open_vals_x.max()
    min_val_x = open_vals_x.min()
    
    open_vals_y = df_y[df_y.sample_id==s_i].open
    max_val_y = open_vals_y.max()
    min_val_y = open_vals_y.min()
    
    
    case = 1 if (min_val_y > min_val_x and max_val_y < max_val_x) else 0
    cases.append(case)
print(f'{sum(cases)/len(cases)}')
# Out:
# 0.7641408751334045

# %% [markdown]
# ### 질문들

# %%
df.open
# Out:
# 5520    1.006394
# 5521    1.005882
# 5522    1.006138
# 5523    1.000767
# 5524    0.990281
#           ...
# 6895    0.999744
# 6896    0.999233
# 6897    1.000000
# 6898    0.999489
# 6899    1.000000
# Name: open, Length: 1380, dtype: float64

# %%
df.trades.shift(20)
# Out:
# 5520           NaN
# 5521           NaN
# 5522           NaN
# 5523           NaN
# 5524           NaN
#            ...
# 6895     76.726349
# 6896    102.301796
# 6897    153.452698
# 6898    664.961670
# 6899    153.452698
# Name: trades, Length: 1380, dtype: float64

# %%
# 해당 시간 거래량으로 다음 시간 가격을 예측할 수 있을까?
import seaborn as sns
plt.figure(figsize=(10,5))
sns.regplot(x=df.trades.shift(20), y=df.open)
# Out:
# <AxesSubplot:xlabel='trades', ylabel='open'>

# %% [markdown]
# 비교적 랜덤...한 듯이 보인다..? 노답이라는 뜻ㅎ
